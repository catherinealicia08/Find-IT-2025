# %% [markdown]
# # **About Detail Dataset**
#
# The file has data which contains of the application that are accessible by children to analyze the application likelihood in fulfilling COPPA standard in the United States.
#
# The data consists of primaryGenreName:
# * Games
# * Education
# * Entertainment
# * Business
# * Lifestyle
# * Tools
# * Music & Audio
# * Food & Drink
# * Shopping
# * Productivity
# * Health & Fitness
# * Utilities
# * Books & Reference
# * Finance
# * Personalization
# * Social
# * Travel & Local
# * Communication
# * News & Magazines
# * Medical
# * Photography
# * Travel
# * Social Networking
# * Maps & Navigation
# * Sports
# * Auto & Vehicles
# * Art & Design
# * News
# * Video Players & Editors
# * Music
# * Photo & Video
# * House & Home
# * Weather
# * Events
# * Beauty
# * Dating
# * Reference
# * Stickers
# * Book
# * Navigation
# * Comics
# * Graphics & Design
# * Parenting
# * Libraries & Demo
# * Developer Tools
# * Magazines & Newspapers
#
# The dataset also contains informations about the details of each applications, including:
# 1. Developer country
# 2. App reputation (user rating, number of downloads)
# 3. Supporting device
# 4. Terms and Condition settings fulfillment (service, privacy, safety)

# %%
import pandas as pd

# Load the datasets
target = pd.read_csv('target.csv')
train = pd.read_csv('train.csv')

# %%
# Pastikan index sinkron
train = train.reset_index(drop=True)
target = target.reset_index(drop=True)
merged_data = pd.concat([train, target], axis=1)

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 17 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   developerCountry                 7000 non-null   object
#  1   countryCode                      6936 non-null   object
#  2   userRatingCount                  7000 non-null   int64
#  3   primaryGenreName                 7000 non-null   object
#  4   downloads                        4851 non-null   object
#  5   deviceType                       7000 non-null   object
#  6   hasPrivacyLink                   6250 non-null   object
#  7   hasTermsOfServiceLink            2365 non-null   object
#  8   hasTermsOfServiceLinkRating      2365 non-null   object
#  9   isCorporateEmailScore            5872 non-null   float64
#  10  adSpent                          1321 non-null   float64
#  11  appAge                           6950 non-null   float64
#  12  averageUserRating                5768 non-null   float64
#  13  appContentBrandSafetyRating      838 non-null    object
#  14  appDescriptionBrandSafetyRating  7000 non-null   object
#  15  mfaRating                        7000 non-null   object
#  16  coppaRisk                        7000 non-null   bool
# dtypes: bool(1), float64(4), int64(1), object(11)
# memory usage: 882.0+ KB

# %%
merged_data.head(100)
# Out:
#                    developerCountry countryCode  userRatingCount  \
# 0                            NORWAY          RO           127731
# 1   ADDRESS NOT LISTED IN PLAYSTORE      GLOBAL                0
# 2              UNITED ARAB EMIRATES          CZ            51143
# 3                           GERMANY      GLOBAL             1074
# 4           CANNOT IDENTIFY COUNTRY      GLOBAL               17
# ..                              ...         ...              ...
# 95  ADDRESS NOT LISTED IN PLAYSTORE      GLOBAL                1
# 96                   UNITED KINGDOM      GLOBAL                0
# 97          CANNOT IDENTIFY COUNTRY      GLOBAL                0
# 98          CANNOT IDENTIFY COUNTRY      GLOBAL                0
# 99                           CANADA      GLOBAL                0
#
#    primaryGenreName             downloads  deviceType hasPrivacyLink  \
# 0            Sports                   NaN  smartphone           True
# 1           Medical              50 - 100      GLOBAL           True
# 2             Games  50000000 - 100000000      GLOBAL           True
# 3             Games                   NaN      GLOBAL           True
# 4             Tools           1000 - 5000      GLOBAL           True
# ..              ...                   ...         ...            ...
# 95        Reference                   NaN      GLOBAL           True
# 96         Business                   NaN      GLOBAL           True
# 97            Games              50 - 100      GLOBAL           True
# 98    Entertainment                 1 - 5      GLOBAL           True
# 99            Tools               10 - 50      GLOBAL           True
#
#    hasTermsOfServiceLink hasTermsOfServiceLinkRating  isCorporateEmailScore  \
# 0                   True                         low                   99.0
# 1                    NaN                         NaN                   99.0
# 2                   True                         low                    0.0
# 3                    NaN                         NaN                   99.0
# 4                    NaN                         NaN                   99.0
# ..                   ...                         ...                    ...
# 95                   NaN                         NaN                    NaN
# 96                   NaN                         NaN                   99.0
# 97                   NaN                         NaN                   99.0
# 98                   NaN                         NaN                    0.0
# 99                   NaN                         NaN                    0.0
#
#       adSpent      appAge  averageUserRating appContentBrandSafetyRating  \
# 0   14.017220  160.400000                4.0                      medium
# 1         NaN   17.500000                0.0                         NaN
# 2   31.883163   30.766667                4.0                         NaN
# 3         NaN   71.533333                4.0                         NaN
# 4         NaN   52.400000                4.0                         NaN
# ..        ...         ...                ...                         ...
# 95        NaN   69.666667                1.0                         NaN
# 96        NaN   27.900000                0.0                         NaN
# 97        NaN   58.133333                NaN                         NaN
# 98        NaN   66.366667                NaN                         NaN
# 99        NaN   16.400000                0.0                         NaN
#
#    appDescriptionBrandSafetyRating mfaRating  coppaRisk
# 0                              low       low      False
# 1                              low       low      False
# 2                              low       low      False
# 3                              low       low      False
# 4                              low       low      False
# ..                             ...       ...        ...
# 95                             low       low      False
# 96                             low       low      False
# 97                             low       low      False
# 98                          medium       low      False
# 99                             low       low      False
#
# [100 rows x 17 columns]

# %%
# Check missing values
merged_data['developerCountry'] = merged_data['developerCountry'].replace(['ADDRESS NOT LISTED IN PLAYSTORE', 'CANNOT IDENTIFY COUNTRY'], 'UNKNOWN')
merged_data['downloads'] = merged_data['downloads'].fillna('0 - 0')
merged_data
# Out:
#           developerCountry countryCode  userRatingCount primaryGenreName  \
# 0                   NORWAY          RO           127731           Sports
# 1                  UNKNOWN      GLOBAL                0          Medical
# 2     UNITED ARAB EMIRATES          CZ            51143            Games
# 3                  GERMANY      GLOBAL             1074            Games
# 4                  UNKNOWN      GLOBAL               17            Tools
# ...                    ...         ...              ...              ...
# 6995               UNKNOWN      GLOBAL                0        Utilities
# 6996               UNKNOWN      GLOBAL                0         Business
# 6997               UNKNOWN      GLOBAL                0  Personalization
# 6998               UNKNOWN      GLOBAL                0         Business
# 6999               UNKNOWN      GLOBAL                0    Entertainment
#
#                  downloads  deviceType hasPrivacyLink hasTermsOfServiceLink  \
# 0                    0 - 0  smartphone           True                  True
# 1                 50 - 100      GLOBAL           True                   NaN
# 2     50000000 - 100000000      GLOBAL           True                  True
# 3                    0 - 0      GLOBAL           True                   NaN
# 4              1000 - 5000      GLOBAL           True                   NaN
# ...                    ...         ...            ...                   ...
# 6995                 0 - 0      GLOBAL           True                   NaN
# 6996                 0 - 0      GLOBAL           True                   NaN
# 6997               10 - 50      GLOBAL           True                   NaN
# 6998               10 - 50      GLOBAL           True                 False
# 6999            500 - 1000      GLOBAL           True                 False
#
#      hasTermsOfServiceLinkRating  isCorporateEmailScore    adSpent  \
# 0                            low                   99.0  14.017220
# 1                            NaN                   99.0        NaN
# 2                            low                    0.0  31.883163
# 3                            NaN                   99.0        NaN
# 4                            NaN                   99.0        NaN
# ...                          ...                    ...        ...
# 6995                         NaN                   99.0        NaN
# 6996                         NaN                    NaN        NaN
# 6997                         NaN                    0.0        NaN
# 6998                        high                   99.0        NaN
# 6999                        high                    0.0        NaN
#
#           appAge  averageUserRating appContentBrandSafetyRating  \
# 0     160.400000                4.0                      medium
# 1      17.500000                0.0                         NaN
# 2      30.766667                4.0                         NaN
# 3      71.533333                4.0                         NaN
# 4      52.400000                4.0                         NaN
# ...          ...                ...                         ...
# 6995   26.266667                0.0                         NaN
# 6996   23.800000                0.0                         NaN
# 6997   27.500000                NaN                         NaN
# 6998  124.033333                0.0                         NaN
# 6999   61.066667                NaN                         NaN
#
#      appDescriptionBrandSafetyRating mfaRating  coppaRisk
# 0                                low       low      False
# 1                                low       low      False
# 2                                low       low      False
# 3                                low       low      False
# 4                                low       low      False
# ...                              ...       ...        ...
# 6995                             low       low      False
# 6996                             low       low      False
# 6997                          medium       low      False
# 6998                             low       low      False
# 6999                             low       low      False
#
# [7000 rows x 17 columns]

# %%
#Check mid value of downloads
def convert_downloads_to_int(download_range):
    try:
        min_str, max_str = download_range.split(' - ')
        min_val = int(min_str.replace(",", ""))
        max_val = int(max_str.replace(",", ""))
        return (min_val + max_val) // 2  # ambil rata-rata tengah
    except:
        return 0  # kalau gagal parsing, isi 0

merged_data['downloads'] = merged_data['downloads'].apply(convert_downloads_to_int)
merged_data
# Out:
#           developerCountry countryCode  userRatingCount primaryGenreName  \
# 0                   NORWAY          RO           127731           Sports
# 1                  UNKNOWN      GLOBAL                0          Medical
# 2     UNITED ARAB EMIRATES          CZ            51143            Games
# 3                  GERMANY      GLOBAL             1074            Games
# 4                  UNKNOWN      GLOBAL               17            Tools
# ...                    ...         ...              ...              ...
# 6995               UNKNOWN      GLOBAL                0        Utilities
# 6996               UNKNOWN      GLOBAL                0         Business
# 6997               UNKNOWN      GLOBAL                0  Personalization
# 6998               UNKNOWN      GLOBAL                0         Business
# 6999               UNKNOWN      GLOBAL                0    Entertainment
#
#       downloads  deviceType hasPrivacyLink hasTermsOfServiceLink  \
# 0             0  smartphone           True                  True
# 1            75      GLOBAL           True                   NaN
# 2      75000000      GLOBAL           True                  True
# 3             0      GLOBAL           True                   NaN
# 4          3000      GLOBAL           True                   NaN
# ...         ...         ...            ...                   ...
# 6995          0      GLOBAL           True                   NaN
# 6996          0      GLOBAL           True                   NaN
# 6997         30      GLOBAL           True                   NaN
# 6998         30      GLOBAL           True                 False
# 6999        750      GLOBAL           True                 False
#
#      hasTermsOfServiceLinkRating  isCorporateEmailScore    adSpent  \
# 0                            low                   99.0  14.017220
# 1                            NaN                   99.0        NaN
# 2                            low                    0.0  31.883163
# 3                            NaN                   99.0        NaN
# 4                            NaN                   99.0        NaN
# ...                          ...                    ...        ...
# 6995                         NaN                   99.0        NaN
# 6996                         NaN                    NaN        NaN
# 6997                         NaN                    0.0        NaN
# 6998                        high                   99.0        NaN
# 6999                        high                    0.0        NaN
#
#           appAge  averageUserRating appContentBrandSafetyRating  \
# 0     160.400000                4.0                      medium
# 1      17.500000                0.0                         NaN
# 2      30.766667                4.0                         NaN
# 3      71.533333                4.0                         NaN
# 4      52.400000                4.0                         NaN
# ...          ...                ...                         ...
# 6995   26.266667                0.0                         NaN
# 6996   23.800000                0.0                         NaN
# 6997   27.500000                NaN                         NaN
# 6998  124.033333                0.0                         NaN
# 6999   61.066667                NaN                         NaN
#
#      appDescriptionBrandSafetyRating mfaRating  coppaRisk
# 0                                low       low      False
# 1                                low       low      False
# 2                                low       low      False
# 3                                low       low      False
# 4                                low       low      False
# ...                              ...       ...        ...
# 6995                             low       low      False
# 6996                             low       low      False
# 6997                          medium       low      False
# 6998                             low       low      False
# 6999                             low       low      False
#
# [7000 rows x 17 columns]
